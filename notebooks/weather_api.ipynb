# %%
import requests
import pandas as pd

# %%
API_KEY = "YOUR API KEY"

lat = 18.52
lon = 73.86

# %%
url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API_KEY}&units=metric"

response = requests.get(url)

data = response.json()

# %%
print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1773165600, 'main': {'temp': 28.01, 'feels_like': 26.9, 'temp_min': 28.01, 'temp_max': 28.01, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 941, 'humidity': 25, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 0.4, 'deg': 100, 'gust': 0.91}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-10 18:00:00'}, {'dt': 1773176400, 'main': {'temp': 27.59, 'feels_like': 26.65, 'temp_min': 26.75, 'temp_max': 27.59, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 939, 'humidity': 26, 'temp_kf': 0.84}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 1.24, 'deg': 93, 'gust': 1.88}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-10 21:00:00'}, {'dt': 1773187200, 'main': {'temp': 25.88, 'feels_like': 25.28, 'temp_min': 24.82, 'temp_max': 25.88, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 939, 'humidity': 29, 'temp_kf': 1.06}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.14, 'deg': 198, 'gust': 1.12}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-11 00:00:00'}, {'dt': 1773198000, 'main': {'temp': 27.9, 'feels_like': 27.02, 'temp_min': 27.9, 'temp_max': 27.9, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 942, 'humidity': 30, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 1}, 'wind': {'speed': 0.89, 'deg': 166, 'gust': 1.88}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-11 03:00:00'}, {'dt': 1773208800, 'main': {'temp': 34.17, 'feels_like': 31.89, 'temp_min': 34.17, 'temp_max': 34.17, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 942, 'humidity': 17, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 2}, 'wind': {'speed': 3.18, 'deg': 67, 'gust': 4.77}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-11 06:00:00'}, {'dt': 1773219600, 'main': {'temp': 36.57, 'feels_like': 33.97, 'temp_min': 36.57, 'temp_max': 36.57, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 938, 'humidity': 13, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.15, 'deg': 85, 'gust': 4.54}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-11 09:00:00'}, {'dt': 1773230400, 'main': {'temp': 35.93, 'feels_like': 33.21, 'temp_min': 35.93, 'temp_max': 35.93, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 937, 'humidity': 11, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.81, 'deg': 97, 'gust': 3.66}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-03-11 12:00:00'}, {'dt': 1773241200, 'main': {'temp': 28.8, 'feels_like': 27.82, 'temp_min': 28.8, 'temp_max': 28.8, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 939, 'humidity': 32, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 2.21, 'deg': 245, 'gust': 4.21}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-11 15:00:00'}, {'dt': 1773252000, 'main': {'temp': 26.24, 'feels_like': 26.24, 'temp_min': 26.24, 'temp_max': 26.24, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 940, 'humidity': 48, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 2.47, 'deg': 251, 'gust': 3.18}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2026-03-11 18:00:00'}, {'dt': 1773262800, 'main': {'temp': 25.26, 'feels_l ...

# %%
rows = []

for item in data["list"]:

    rows.append({
        "timestamp": item["dt_txt"],
        "temperature": item["main"]["temp"],
        "humidity": item["main"]["humidity"],
        "cloud_cover": item["clouds"]["all"],
        "wind_speed": item["wind"]["speed"],
        "precipitation": item.get("rain", {}).get("3h", 0)
    })

forecast_df = pd.DataFrame(rows)

forecast_df["timestamp"] = pd.to_datetime(forecast_df["timestamp"])

forecast_df.head()
# Out:
#             timestamp  temperature  humidity  cloud_cover  wind_speed  \
# 0 2026-03-10 18:00:00        28.01        25            1        0.40
# 1 2026-03-10 21:00:00        27.59        26            1        1.24
# 2 2026-03-11 00:00:00        25.88        29            0        1.14
# 3 2026-03-11 03:00:00        27.90        30            1        0.89
# 4 2026-03-11 06:00:00        34.17        17            2        3.18
#
#    precipitation
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
forecast_df.to_csv("../outputs/weather_forecast.csv", index=False)

print("Weather forecast saved!")
# Out:
# Weather forecast saved!
