# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import joblib

# %%
df = pd.read_csv("../data/processed_solar_data.csv")

df.head()
# Out:
#              timestamp  temperature   humidity  cloud_cover  wind_speed  \
# 0  2024-01-01 00:00:00    18.496714  58.617357    56.192213    8.046060
# 1  2024-01-01 01:00:00    22.167403  67.674347    28.263140    6.085120
# 2  2024-01-01 02:00:00    23.241962  40.867198     0.000000    3.875425
# 3  2024-01-01 03:00:00    24.163044  45.876963    76.641219    4.548447
# 4  2024-01-01 04:00:00    26.115871  61.109226    11.225161    5.751396
#
#    precipitation  solar_output  hour  day_of_week  is_weekend  sin_hour  \
# 0       0.082923      0.000000     0            0           0  0.000000
# 1       0.000000      0.000000     1            0           0  0.258819
# 2       0.000000      6.284947     2            0           0  0.500000
# 3       0.233764      0.000000     3            0           0  0.707107
# 4       0.000000      0.000000     4            0           0  0.866025
#
#    cos_hour  temp_cloud_interaction  rolling_temp  lag_solar
# 0  1.000000                8.103001      0.000000   0.000000
# 1  0.965926               15.902199      0.000000   0.000000
# 2  0.866025               23.241962     21.302027   0.000000
# 3  0.707107                5.644192     23.190803   6.284947
# 4  0.500000               23.184323     24.506959   0.000000

# %%
df = df.sort_values("timestamp")

# %%
features = [
    "temperature",
    "humidity",
    "cloud_cover",
    "wind_speed",
    "precipitation",
    "sin_hour",
    "cos_hour",
    "day_of_week",
    "is_weekend",
    "temp_cloud_interaction",
    "rolling_temp",
    "lag_solar"
]

# %%
split_index = int(len(df)*0.83)

train_df = df.iloc[:split_index]
val_df = df.iloc[split_index:]

# %%
X_train = train_df[features]
y_train = train_df["solar_output"]

X_val = val_df[features]
y_val = val_df["solar_output"]

# %%
model = RandomForestRegressor(
    n_estimators=300,
    max_depth=12,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=300, random_state=42)

# %%
predictions = model.predict(X_val)

# %%
mae = mean_absolute_error(y_val, predictions)

rmse = np.sqrt(mean_squared_error(y_val, predictions))

r2 = r2_score(y_val, predictions)

print("MAE:", mae)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 14.008249601741603
# RMSE: 18.581388886587558
# R2: 0.9874368575413819

# %%
joblib.dump(model, "../models/solar_model.pkl")

print("Model saved!")
# Out:
# Model saved!
